# %%
# file Handling

# file open

# file working Read Write Append

# file close

# %%
# file open-

# filepointername=open("filename","mode")    

modes of file open

read---r---if file is exist then i will open it for reading purpose, 
if file not exists then it gives error

write--w--if file exist then it open for writing purpose and all 
old content will be deleted
if file not exist then it will create a new one

append--a---if file exist then it open for append purpose and 
all old content will not be deleted
if file not exist then it will create a new one

# %%
f=open("demo.txt","a")

f.write('''THIOS IS NEW
content 
and old content will not delete''')

f.close()

# %%
f=open("demo2.txt","r")

# print(f.read())
print(f.read(30))
# print(f.readline())
# print(f.readline())
# print(f.readline())



f.close()
# Out:
# This is a data
# which you ant

# %%
f=open("detail.txt","w")
str1=input("Enter your NAme: ")
f.write(str1)
f.close()
# Out:
# Enter your NAme: werwr

# %%
f=open("detail.txt","r")
print(f.read())
f.close()
# Out:
# name    :    Rajveer Shekhawat
# Age     :    45
# email   :    rs@gmail.com
# movbile :    89652365874

# %%
name=input("Enter your NAme: ")
age=int(input("Enter Age: "))
mobile=int(input("Enter mobile: "))
email=input("Enter Email: ")
str1=f"Name\t:\t{name}\nAge\t:\t{age}\nmobile\t:\t{mobile}\nemail\t:\t{email}"
file=open("Detail2.txt","w")
file.write(str1)
file.close()
print(str1)
# Out:
# Enter your NAme: Rajveer Shekhawat
# Enter Age: 45
# Enter mobile: 789654125
# Enter Email: rs@gmail.com
# Name	:	Rajveer Shekhawat
# Age	:	45
# mobile	:	789654125
# email	:	rs@gmail.com
