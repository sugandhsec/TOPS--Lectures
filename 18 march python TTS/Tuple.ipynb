# %%
tuple is acollection of lemenets of similar or diffrent datatype
tuple is immutable---no chengs allowed
tuple is ordered -- every elements in list has its own index number
tuple is defined in ()brackets
tuple allows duplicats values BaseExceptionall have different index number







methods ---class


function---
class ---function---method

listname.append()---method

function() in list

min(listname)
max
len
list

# %%
tuple1=(45,45,67,"hello",[23,32,4],(44,4,4,4),{1,2,},{1:"hello",2:"men"})
print(tuple1[3])
print(tuple1[4][2])
#tup1[2]="great"
#tup1[4][1]="wow"
print(tup1)
print(tup1[2:7])
# Out:
# hello
# 4

# %%
list1=[56,89,74,56,98,54,51,26,53]
min(list1)
max(list1)
len(list1)
# Out:
# 9

# %%
list1=["heelo","wow","jumps","Downs","dry",85,96,21,35,45]
len(list1)
# Out:
# 10

# %%
# TUPLE
# list is mutable but tuple is immutable(changes not allowed)
# tuple is ordered
# tuple is defined in ()

# %%
tup1=(45,69,87,45,96,548)
print(tup1)
print(tup1[2])
print(tup1[3:]) #tuple slicing
print(tup1[1:5])
# Out:
# (45, 69, 87, 45, 96, 548)
# 87
# (45, 96, 548)
# (69, 87, 45, 96)

# %%
# Tuple methods
tup1=(52.65,47,0,8,"hello",True,"wow",1,"great",47,47,False)
tup1.count(0) #counts the occurence of element
# Out:
# 2

# %%
tup1=(23,3,3,3,3,3,5,5,345,5,)

tup1.index(4859)
print(tup1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-67a0ce73b4d6> in <cell line: 3>()
#       1 tup1=(23,3,3,3,3,3,5,5,345,5,)
#       2
# ----> 3 tup1.index(4859)
#       4 print(tup1)
#
# ValueError: tuple.index(x): x not in tuple

# %%
tup11=(4,5,6,89)
tup2=tup11.copy()
print(tup2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 tup11=(4,5,6,89)
# ----> 2 tup2=tup11.copy()
#       3 print(tup2)
#
# AttributeError: 'tuple' object has no attribute 'copy'

# %%
tup1.

# %%
a=(1,2,3)
b=(1,2,3)

print(id(a))
print(id(b))
# Out:
# 2698179213376
# 2698179263808

# %%
tup1=(1,23.65,True,[1,2,3])
tup1[3][0]="hello"
# tup1[1]="hello"
print(tup1[3])
print(tup1)
# Out:
# ['hello', 2, 3]
# (1, 23.65, True, ['hello', 2, 3])

# %%
a=21
b=21
a is b
# Out:
# True

# %%
list1=(1,2,3)
list2=list1
# list1[0]="WOW"
print(list2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 3>()
#       1 list1=(1,2,3)
#       2 list2=list1
# ----> 3 list1[0]="WOW"
#       4 print(list2)
#
# TypeError: 'tuple' object does not support item assignment

# %%
list1=['h','e','l','l','o']
"hello"

# %%
str1=input("Enter String")
a=str1.find("not")
b=str1.find("poor")
if a<b:
    str2=str1.replace(str1[a:b+4],"good")
    print(str2)
# Out:
# Enter Stringhe is not a very poor person
# he is good person

# %%
# word
str1=input("Enter Your sentence: ")
words=str1.split(" ")
uword=input("Enter Your word: ")
print(words.count(uword))
# Out:
# Enter Your sentencehe is a his good person
# Enter Your wordis
# 1

# %%
# substring
str1=input("Enter Your sentence: ")
uword=input("Enter Your word: ")
print(str1.count(uword))
# Out:
# Enter Your sentencehis is is a good is is
# Enter Your wordis
# 5
