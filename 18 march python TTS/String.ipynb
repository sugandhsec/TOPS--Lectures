# %%
 # String
# String
# string is defined in '' " "  ''' '''  """  """
str1="hello"
print(str1)topsst301
# Out:
# hello

# %%
# string is immutable---changes not allowed
string1="hello Wolrd"
# index position ---0
# index position
# stringname[index position]
print(string1[4]) #stirng slicing
print(string1[2:7])
print(string1[9:6:-1])
print(string1[-1:-6:-2])
# Out:
# o
# llo W
# rlo
# dlW

# %%
# string methods
# dir("")
# capitalize()--it capitalize first letter of string and lowercase others letters
string1="hello worHWBFHld JHFDWIO jgvjkgnerjkn"
print(string1.capitalize())
print(string1)
# Out:
# Hello worhwbfhld jhfdwio jgvjkgnerjkn
# hello worHWBFHld JHFDWIO jgvjkgnerjkn

# %%
# casefold()---lowercase all alphabtes of string
# lower()---lowercase all alphabtes of string
string1="hello wolrd JKLJEKL ß 375 &R%&^% njklrsdgnjk JBKJBDSJ"
print(string1.casefold())
print(string1.lower())
# Fu --ss
# Out:
# hello wolrd jkljekl ss 375 &r%&^% njklrsdgnjk jbkjbdsj
# hello wolrd jkljekl ß 375 &r%&^% njklrsdgnjk jbkjbdsj

# %%
# center(length[,character])
string1="Hello Wolrd"
print(string1.center(50))
print(string1.center(50,"/"))
# Out:
#                    Hello Wolrd
# ///////////////////Hello Wolrd////////////////////

# %%
str1="hello"
str1*3
# Out:
# 'hellohellohello'

# %%
# pyramid pattern
num=int(input("Enter Choice: "))
str1="* "
for i in range(1,num+1):
    print((str1*i).center(num*2))
# Out:
# Enter Choice: 15
#               *
#              * *
#             * * *
#            * * * *
#           * * * * *
#          * * * * * *
#         * * * * * * *
#        * * * * * * * *
#       * * * * * * * * *
#      * * * * * * * * * *
#     * * * * * * * * * * *
#    * * * * * * * * * * * *
#   * * * * * * * * * * * * *
#  * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * *

# %%
# count("substring"[,startingpoint,endingpoint])--gives count of substing
str1="HEllo World ol ol ol"
print(str1.count("o",6,12))
# Out:
# 1

# %%
# endswith("substring",[startingpoint,endingpoint])
str1="hello Wolrd hgt eger ty"
print(str1.endswith("lrd",8,12))
# Out:
# False

# %%
# find("substring",[startingpoint,endingpoint]) gives index of substring
# and if element not found then it returns -1
str1="hello Wolrd"
print(str1.find("olr"))
print(str1.find("z"))
# Out:
# 7
# -1

# %%
# index("substring",[startingpoint,endingpoint]) gives index of substring)
# and if element not found then it returns Valuerror-Substring not found
str1="hello Wolrd"
print(str1.index("olr",5,12))
print(str1.index("z"))     #other eliments find after error
# Out:
# 7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 5>()
#       3 str1="hello Wolrd"
#       4 print(str1.index("olr",5,12))
# ----> 5 print(str1.index("z"))
#
# ValueError: substring not found

# %%
# ljust(width[,fillchar])---it will left justified the string in given lenght
str1="hello World"
print(str1.ljust(50,"*"))
# Out:
# hello World***************************************

# %%
# rjust(width[,fillchar])---it will right justified the string in given lenght
str1="hello World"
print(str1.rjust(50,"*"))
# Out:
# ***************************************hello World

# %%
num=int(input("Enter Choice: "))
str1="* "
for i in range(1,num+1):
    print((str1*i).rjust(num*2))
# Out:
# Enter Choice: 9
#                 *
#               * *
#             * * *
#           * * * *
#         * * * * *
#       * * * * * *
#     * * * * * * *
#   * * * * * * * *
# * * * * * * * * *

# %%
str1="                                  hello                             "
# print(str1)
print(str1.lstrip())
print(str1.rstrip())
print(str1.strip())
# Out:
# hello
#                                   hello
# hello

# %%
str1="dwef dw585"
print(str1.islower()) #all alphabets is in lowercase or not
# Out:
# False

# %%
str1="jkejn544"
print(str1.isalnum()) #checks all character of string is alphabets or numbers
# Out:
# True

# %%
str1="Wwerg"
print(str1.isalpha()) #checks all characters is alphabets
# Out:
# True

# %%
str1="ERger erfgλ"
print(str1.isascii()) #checks all characters have their ascii values
# Out:
# False

# %%
rule 1---first position a-z A-Z _
remaing a-z A-Z _ 0-9

# %%
str1="_f89efhber"
print(str1.isidentifier()) #checks if string is a valid identifier or not
# Out:
# True

# %%
str1="ERgert"
print(str1)
str1.isprintable() #checks wheteher string will be printexactly same or not
# Out:
# ERgert
# True

# %%
str1="     "
str1.isspace() #string have all spaces characters or not
# Out:
# True

# %%
str1="r ergte erytgerERGTER ergERGTER ERGER "
print(str1.capitalize())#capitaliza the first letter of string
print(str1.title()) #capitaliza the first letter of every word
# Out:
# R ergte erytgerergter ergergter erger
# R Ergte Erytgerergter Ergergter Erger

# %%
str1="Rfergf Ugterfgfer Oerger"
str1.istitle() #checks if string is in titlecase or not
# Out:
# True

# %%
str1="798988"
print(str1.isdecimal())
print(str1.isdigit())
print(str1.isnumeric())
# Out:
# False
# False
# False

# %%
str1="Hello i am good in Maths but weak in mathematics"
# str1.partition("good") #gives tuple of 3 elememts
# 1st elemnst left of substring
# 2nd substring itself
# 3rd right of substring
print(str1.partition("rainbow"))
# Out:
# ('Hello i am good in Maths but weak in mathematics', '', '')

# %%
str1="e ewrwrge\trgrtherth\tver"
str1.expandtabs(60) #expand the size of tab
# Out:
# 'e ewrwrge                                                   rgrtherth                                                   ver'

# %%
str1="ergeg erer ERTEHG erger4654 ERHGet #$^%# RGEDjytj"
str1.swapcase() #swap the cases means upper to lower and lower to upper
# Out:
# 'ERGEG ERER ertehg ERGER4654 erhgET #$^%# rgedJYTJ'

# %%
# join(iterable)
itr="PYTHON"
str1="**".join(itr)
print(str1)
# Out:
# P**Y**T**H**O**N

# %%
str1="ERg erger tert er"dgftffgg
print(len(str1))
# Out:
# 17
