# %%
# Exception HAndling

# Error
# Exception

# %%
print(hello")
# Out:
#   Input In [1]
#     print(hello")
#                  ^
# SyntaxError: EOL while scanning string literal

# %%
print(58/6)
print(48/4)
print(89/0)
# Out:
# 9.666666666666666
# 12.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 print(58/6)
#       2 print(48/4)
# ----> 3 print(89/0)
#
# ZeroDivisionError: division by zero

# %%
# Out:
# Enter number1 : jkefjhrk
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 num1=int(input("Enter number1 : "))
#       2 num2=int(input("Enter number2 : "))
#       3 print(f"addition = {num1+num2}")
#
# ValueError: invalid literal for int() with base 10: 'jkefjhrk'

# %%
try:
    num1=int(input("Enter number1 : "))
    num2=int(input("Enter number2 : "))
    print(f"addition = {num1+num2}")
except:
    print("Only numbers allowed")
# Out:
# Enter number1 : 3223
# Enter number2 : 23
# addition = 3246

# %%
# print(point) --NameError
# a=int(input("Enter Number: ")) --ValueError
# Out:
# Enter Number: egrtfhrtj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 # print(point) --NameError
# ----> 2 a=int(input("Enter Number: "))
#
# ValueError: invalid literal for int() with base 10: 'egrtfhrtj'

# %%
dict1={1:"hELLO",2:"wORLD",3:"gREAT"}
# print(dict1[56])          #key Error aave 
print(dict1.get(489""This key not found"))          #none aave mes aapai
# print(dict1)
# Out:
# None

# %%
# eXCEPTION hANDLING
try:
    print("Hello Wolrd")
except:
    print("Error")
# Out:
# Hello Wolrd

# %%
num1=float(input("Enter number1: "))
num2=float(input("Enter number2: "))
print(num1+num2)
# Out:
# Enter number1: 2
# Enter number2: 2
# 4.0

# %%
num1=float(input("Enter number1: "))
num2=float(inut("Enter number2: "))
print(num1+num2)
# Out:
# Enter number1: hgj
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-bedd0f4acc74> in <cell line: 1>()
# ----> 1 num1=float(input("Enter number1: "))
#       2 num2=float(inut("Enter number2: "))
#       3 print(num1+num2)
#
# ValueError: could not convert string to float: 'hgj'

# %%
try:
    num1=float(input("Enter number1: "))
    num2=float(inpt("Enter number2: "))
    print(num1+num2)
except ValueError:
    print("Only Numbers allowed")
except NameError:
    print("Some other error")
except:
    print("Got any unfound error")
# Out:
# Enter number1: etrh
# Only Numbers allowed

# %%
num=int(input("Enter Number: "))
try:
    if num%2==0:
        print("hello World")
        raise
except:
    print("Some error")
# Out:
# Enter Number: 48
# hello World
# Some error

# %%
import random
# import jvfkherjkge
random.demo()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 3>()
#       1 import random
#       2 # import jvfkherjkge
# ----> 3 random.demo()
#
# AttributeError: module 'random' has no attribute 'demo'

# %%
from random import great
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 from random import great
#
# ImportError: cannot import name 'great' from 'random' (C:\ProgramData\Anaconda3\lib\random.py)

# %%
a=5
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [40], in <cell line: 3>()
#       1 a=5
#       2 b=0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero
