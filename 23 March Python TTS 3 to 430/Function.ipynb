# %%
# DRY--don't repeat yourself

def functionname([parameters]):
    gferg
    ergerg
    ergerg
    body of the function
    [return value]
    
    
# identifier rule

# %%
def demo():
    print("Hello This is abasic function")

# %%
demo()
demo()
# Out:
# Hello This is abasic function
# Hello This is abasic function

# %%
def demo2(a,b,c):
    print(a,b,c)

# %%
demo2(89)
# demo2("jferijgrthbn")
# Out:
# 445

# %%
demo2("hello",[45,89],{89,25})
# Out:
# hello [45, 89] {89, 25}

# %%
def great(a):
    return a**3

# %%
z=great(2)
print(z)
# Out:
# 8

# %%
def check():
    print("1")
    print("2")    
    print("3") 
    
    print("4")    
    print("5")  
    return "hello"

# %%
check()
# Out:
# 1
# 2
# 3
# 'hello'

# %%
# types of parameters
check("hwgfh")

# %%
def fun1(a):
    if a==a[::-1]:
        return "aplindrome"
    else:
        return "Not palindrome"

# %%
var=input("Enter A string")
ans=fun1(var)
print(ans)
# Out:
# Enter A stringdad
# aplindrome

# %%
print(fun1("regerg"))
# Out:
# Not palindrome

# %%
fun1("mam")
# Out:
# Palindrome

# %%
8 ----1 2 4 
24--1 2 3 4 6 8 12
248

# %%
# tYPES OF ARGUMENT
# 1)POSITIONAL ARGUMENT
# 2)KEYWORD ARGUMENT
# 3)DEFAULT ARGUMENT
# 4)ARBITRARY KEYWORD ARGUMENT
# 5)ARBITRARY POSITIONAL ARGUMENT

# %%
# positional argument
def demo(m,p):
    print(f"Value of m is{m} and value of p is {p}")

    
a=demo("hello",89.36)
print(a)
# Out:
# Value of m ishello and value of p is 89.36
# None

# %%
demo("hello",89.36)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e2ca8bc5ce44> in <cell line: 1>()
# ----> 1 demo("hello",89.36)
#
# NameError: name 'demo' is not defined

# %%
# keyword argument
def demo(m,p,x,z):
    print(f"Value of m is{m} and value of p is {p} {x}  {z}")
# Out:
#   File "<tokenize>", line 5
#     print(demo(89,36,58.36,"wow"))
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
demo(89,36,58.36,"wow")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-dd8749588854> in <cell line: 1>()
# ----> 1 demo(89,36,58.36,"wow")
#
# TypeError: demo() takes 2 positional arguments but 4 were given

# %%
# deafult argument
def greeting(name="wrtg"):
    print(f"Good morning Mr. {name}")

# %%
greeting()
# Out:
# Good morning Mr. wrtg

# %%
# arbitrary positional argument --- * values Tuple format
def depth(w,k,*d):
    print(w,k,d[2])

# %%
depth(78,96,54,87,45,69)
# Out:
# 78 96 45

# %%
# arbitrary keyword argument  **   dictionary
def volley(m,**t):
    print(m,t)

# %%
volley(t="hello",m=87.24,z="happy",i="Python")
# Out:
# 87.24 {'t': 'hello', 'z': 'happy', 'i': 'Python'}

# %%
modules---collection of function or variable in a file
package---collection of modules __int__.py ---library
library ---collection of package
